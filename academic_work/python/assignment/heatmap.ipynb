# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.read_csv("laptop_price - dataset.csv")
df = df[['Inches', 'CPU_Frequency (GHz)', 'RAM (GB)', 'Weight (kg)', 'Price (Euro)']]
cor = df.corr()
plt.figure(figsize=(7,7))
sns.heatmap(data=cor)
# Out:
# <Axes: >
